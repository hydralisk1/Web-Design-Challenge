# %%
import pandas as pd

# %%
weather_df = pd.read_csv("Resources/cities.csv")

# %%
weather_df.head()
# Out:
#    City_ID            City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  nizhnyaya omka          28      RU  1598326168        85  55.43
# 1        1       neyshabur           0      IR  1598326168        49  36.21
# 2        2     kangaatsiaq         100      GL  1598326168        90  68.31
# 3        3         merauke          52      ID  1598326168        62  -8.47
# 4        4       cape town         100      ZA  1598326168        93 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   74.94     55.11        8.43
# 1   58.80     63.86        2.19
# 2  -53.46     44.06        5.03
# 3  140.33     81.86       18.01
# 4   18.42     48.20        5.82

# %%
weather_df.to_html(index=False)
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City_ID</th>\n      <th>City</th>\n      <th>Cloudiness</th>\n      <th>Country</th>\n      <th>Date</th>\n      <th>Humidity</th>\n      <th>Lat</th>\n      <th>Lng</th>\n      <th>Max Temp</th>\n      <th>Wind Speed</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>nizhnyaya omka</td>\n      <td>28</td>\n      <td>RU</td>\n      <td>1598326168</td>\n      <td>85</td>\n      <td>55.43</td>\n      <td>74.94</td>\n      <td>55.11</td>\n      <td>8.43</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>1</td>\n      <td>neyshabur</td>\n      <td>0</td>\n      <td>IR</td>\n      <td>1598326168</td>\n      <td>49</td>\n      <td>36.21</td>\n      <td>58.80</td>\n      <td>63.86</td>\n      <td>2.19</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2</td>\n      <td>kangaatsiaq</td>\n      <td>100</td>\n      <td>GL</td>\n 
# ...
